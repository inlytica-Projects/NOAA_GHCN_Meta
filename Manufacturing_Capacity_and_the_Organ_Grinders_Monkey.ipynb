# %% [markdown]
# <a href="https://colab.research.google.com/github/inlytica-Projects/NOAA_GHCN_Meta/blob/master/Manufacturing_Capacity_and_the_Organ_Grinders_Monkey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pymc as pm
import arviz as az# Import the other core data science packages
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from scipy import stats
import xarray as xr

# %% [markdown]
# Lets say that you are a young (not startup) manufacturing company trying to decide if and when to move to a new, larger facility and, if so, how large. Your current ramp-up estimates are listed below. How would you go about doing it?
#
# To start off, we need to figure out what the key driver(s) of the decision are.
#
# I can think of a few:
#
#
# *   Units / square foot required manufacturing capacity
# *   Demand
# *   Time
#
#
# ---
# Actually, I am wrong here. I need to re-write. It needs to be something like, I may be confident in ultimate volume(investors probably are really care more about this) but the TIME thing is the tricky part of this.
#
#
# ---
#
#
# ---
#
# Actually, the thing I am really trying to decide is time because given enough time, I will get there. The problem is that I do not want to use my investors capital to sit on unused manufacurting space when I could have deployed it more efficiently. And, I REALLY do not want to go back to the organ grinder routine this time because of a mistake. The first time was bad enough.
#
# So, what I am not really looking for here is not really overall volumn, and not really time-to-achieve it, but my ramp. And, unfortunately, that will probably not be a straight line.
# ---
#
#
#
# ---
# Could I send this to Jeff Kaplan, Paul, etc.?
#
#
# ---
#
#
#
# ---
#
# So, this isn't a spreadsheet excercise. I need to get this right.
#
#
#
# ---
#
#
#
#
#
# My first pass at this, I actually listed only 2: Units / foot and Ramp Up. But on further reflection, I think that units and time should be separated. The reason is that we are not really concerned with actually building a ramp rate. That probably already exists in our financials and we could easily go with it. The trouble is that I (I've never run a manufacuring company before but I am assuming that this is how I would feel) am pretty comfortable with putting projections into a spread sheet. I can always change the sheet later if things do not turn out the way I thought (hoped) they would. And, my investors probably expect this anyway.
#
# But, now, I have to make a decision that would require me to COMMIT a whole lot of actual real money for an extended period of time. And, this is money that I probably had to travel around performing like an organ grinder's monkey (you can look it up here) ---USE DALLE TO GENERATE A PICTURE OF DISGRUNTLED ORGAN GRINDER MONKEY CARTOON --to raise. I do not relish the idea of going back out to my original investors and explain why I have tied up their capital in a lease for square footage that is siting unused. And, I especially do not want to go back out to more investors to try to raise additional money. (I am not a masochist.) So, I need to be confident that I am getting it right. And, to make matters more difficult, I can't just take a wait and see attitude because the search for manufacturing space and then lease negotiation, set-up, move, etc. etc. etc. etc. is going to take some time. Which brings me back to the time issue. And, an issue of confidence.
#
# Because, since I have projections, what I really need to know to make this decision is How confident i my projections, I need to be to pull the trigger on a lease. How confident I am in my projections of volume and time. Or , if my confidence in my current projections of volume and time do not meet my threshold (--two separtate confidence levels is the key to this article--), what projections would I be confident enough in (again both in volume and time).
#
#
#  And, in this case, there is really only one and that is demand over time. In
#
#
#
# other words, you have to decide how many units you are going to have to produce at what ramp up speed. (And by the way, this also drives revenue.)
#
#
#
# **Because we are looking for confidence, the place to start is with my projections. Because, that is really what I want to verify. So, could you ask a similar company how far they had come in x time compared to where they are now.**

# %%
# Construct fake ramp up estimate

increment_estimate = np.array([ 80,  30,  30,  30,  70,  70,  70, 110, 110, 110, 170, 170, 170,
       240, 240, 240, 310, 310, 310, 380, 380])
quarter = np.array(range(0,21))
total_volume = [increment_estimate[0]]
for increment in range(1,21):
  total_volume.append(increment_estimate[increment]+total_volume[increment-1])

current_production_estimate = pd.DataFrame({'quarter':quarter,'increment':increment_estimate,'total_volume':total_volume})

current_production_estimate
# Out:
#     quarter  increment  total_volume
# 0         0         80            80
# 1         1         30           110
# 2         2         30           140
# 3         3         30           170
# 4         4         70           240
# 5         5         70           310
# 6         6         70           380
# 7         7        110           490
# 8         8        110           600
# 9         9        110           710
# 10       10        170           880
# 11       11        170          1050
# 12       12        170          1220
# 13       13        240          1460
# 14       14        240          1700
# 15       15        240          1940
# 16       16        310          2250
# 17       17        310          2560
# 18       18        310          2870
# 19       19        380          3250
# 20       20        380          3630

# %% [markdown]
# You could go with those estimates but who's to say if they are right? Lets face it, they are probably more a product of hope than reality.
